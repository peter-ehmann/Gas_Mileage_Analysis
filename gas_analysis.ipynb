# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import pandas as pd

# %%
link = "https://raw.githubusercontent.com/peter-ehmann/Gas_Mileage_Analysis/master/gas_log.csv"
local = "~/Documents/Programming/Gas/gas_log.csv"
data = pd.read_csv(local,
                   parse_dates=["date"],
                   index_col=["date"])

# %%
data["mpg"] = data["miles"]/data["gallons"]

# %%
data
# Out:
#               company             town state    zip  gallons  price   sale  \
# date
# 2019-05-20      Delta      Long Valley    NJ   7853    7.332  2.979  21.84
# 2019-05-25      Delta      Long Valley    NJ   7853    9.607  2.979  28.62
# 2019-06-02   7-Eleven         Somerset    NJ   7883    7.172  2.739  19.64
# 2019-06-21       Wawa           Elkton    MD  21921    7.347  2.449  17.99
# 2019-06-25       Wawa      Hacketstown    NJ   7840    8.273  2.639  21.83
# 2019-06-28       Wawa      Hacketstown    NJ   7840    7.954  2.759  21.95
# 2019-07-03         BP        Ledgewood    NJ   7852    7.905  2.619  20.70
# 2019-07-12    Phillip      Long Valley    NJ   7853    5.844  2.979  14.43
# 2019-07-26       Wawa           Elkton    MD  21921   14.173  2.469  34.99
# 2019-07-27  QuickChek  North Brunswick    NJ   8902    4.510  2.559  11.54
# 2019-08-02       Wawa           Elkton    MD  21921   10.947  2.499  27.36
# ...

# %%
df = data.dropna(subset=["miles"])

fig, ax = plt.subplots(figsize=(10, 7))

ax.plot(df.index.values,
        df["mpg"], "-o",
        color="purple")

ax.set(#xlabel="Date",
       #ylabel="Miles Per Gallon",
       title="Miles Per Gallon over Time")

ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
ax.xaxis.set_major_formatter(DateFormatter("%m/%d"))

plt.savefig("./figures/mpg_time.png")

plt.show()

# %%
df = data.dropna(subset=["miles"])
df.head()
# Out:
#             company         town state   zip  gallons  price   sale  miles  \
# date
# 2019-05-25    Delta  Long Valley    NJ  7853    9.607  2.979  28.62  229.0
# 2019-06-25     Wawa  Hacketstown    NJ  7840    8.273  2.639  21.83  204.0
# 2019-06-28     Wawa  Hacketstown    NJ  7840    7.954  2.759  21.95  184.0
# 2019-07-03       BP    Ledgewood    NJ  7852    7.905  2.619  20.70  172.6
# 2019-07-12  Phillip  Long Valley    NJ  7853    5.844  2.979  14.43  160.9
#
#                 time   product fillup        mpg
# date
# 2019-05-25  12:20:00  unleaded    yes  23.836786
# 2019-06-25  16:05:26  unleaded    yes  24.658528
# 2019-06-28  17:16:42  unleaded    yes  23.133015
# 2019-07-03  10:26:00  unleaded    yes  21.834282
# 2019-07-12  10:16:00   regular    yes  27.532512
